# %% [markdown]
# ### Sistema de Graficación mediante Gnuplot

# %%
import os

def generar_script_gnuplot(ruta_archivo_base, lim=3000, retardo=0.001, nombre_salida="plot_animacion.gp"):

    # Leer archivo base
    with open(ruta_archivo_base, "r") as f_in:
        lineas = f_in.readlines()

    # Saltar encabezado (línea 0)
    datos = [linea.strip().split() for linea in lineas[1:] if linea.strip()]
    
    # Extraer tipos (última columna)
    tipos = [int(linea[-1]) for linea in datos]

    # ====================================================================
    # 🔥 DETECCIÓN DE RANGOS CONSECUTIVOS POR TIPO
    # ====================================================================
    grupos = []
    inicio = 0
    tipo_actual = tipos[0]

    for i, t in enumerate(tipos):
        if t != tipo_actual:
            grupos.append((tipo_actual, inicio, i-1))
            inicio = i
            tipo_actual = t

    # Agregar el último grupo
    grupos.append((tipo_actual, inicio, len(tipos)-1))
    # ====================================================================

    # Colores por tipo
    colores = {
        1: "black",
        0: "blue",
        -1: "red"
    }

    # ====================================================================
    # 🔥 CONSTRUCCIÓN DEL BLOQUE PLOT, dejando el último sin ",\"
    # ====================================================================
    plot_lines = []
    primera = True

    for idx, (tipo, ini, fin) in enumerate(grupos):
        color = colores.get(tipo, "gray")
        prefix = 'plot file ' if primera else '     "" '

        # Si NO es el último grupo → agregar ",\"
        if idx < len(grupos) - 1:
            plot_lines.append(
                f'{prefix}every ::{ini}::{fin} u 2:3 w p ps 1 pt 7 lc rgb "{color}" not,\\'
            )
        else:
            # Último bloque (sin coma invertida)
            plot_lines.append(
                f'{prefix}every ::{ini}::{fin} u 2:3 w p ps 1 pt 7 lc rgb "{color}" not'
            )

        primera = False

    bloque_plot = "\n  ".join(plot_lines)
    # ====================================================================

    carpeta = os.path.dirname(ruta_archivo_base)

    # Script Gnuplot final
    contenido = f"""lim = {lim}
retardo = {retardo}

set terminal qt size 800,800 enhanced font 'Verdana,10'
set size square

do for [i=0:lim]{{
  titulo = sprintf("paso = %.4d - tiempo = %.5f", i, i*5e-5)
  set title titulo
  file = sprintf("{carpeta}/state_%.4d.txt", i)
  {bloque_plot}
  pause retardo
}}"""

    with open(nombre_salida, "w") as f_out:
        f_out.write(contenido)

    # Mensaje de confirmación
    print(f"✅ Script Gnuplot generado correctamente: {nombre_salida}")
    print("📊 Rangos consecutivos detectados por tipo:")
    for tipo, ini, fin in grupos:
        print(f"  Tipo {tipo}: líneas {ini}–{fin} ({fin - ini + 1} partículas)")

# Ejemplo de uso:
# generar_script_gnuplot("Output/experiments_B/experiment_B2.069138/Output/state_0000.txt", lim=3000, retardo=0.001)

# %%
import subprocess
from pathlib import Path
import subprocess

# %% [markdown]
# ## B = 3.35, $\rho = 1092$

# %%
PROJECT_ROOT = "/media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH"
BASE_ROOT = f"{PROJECT_ROOT}/Output/experiments_B/experiment_B3.359818/Output/state_0000.txt"

generar_script_gnuplot(BASE_ROOT, lim=499, retardo=0.01, nombre_salida="expB3.36.gp")

# %%
archivo_gp = "expB3.36.gp"
subprocess.run(["gnuplot", archivo_gp])

# %% [markdown]
# ## B = 2.07, $\rho = 1116 kg/m^3$

# %%
PROJECT_ROOT = "/media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH"
BASE_ROOT = f"{PROJECT_ROOT}/Output/experiments_B/experiment_B2.069138/Output/state_0000.txt"

generar_script_gnuplot(BASE_ROOT, lim=499, retardo=0.01, nombre_salida="expB2.07.gp")

# %%
import subprocess

archivo_gp = "expB2.07.gp"
subprocess.run(["gnuplot", archivo_gp])

# %% [markdown]
# ## B = 1.27, $\rho = 1146$

# %%
PROJECT_ROOT = "/media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH"
BASE_ROOT = f"{PROJECT_ROOT}/Output/experiments_B/experiment_B1.274275/Output/state_0000.txt"

generar_script_gnuplot(BASE_ROOT, lim=499, retardo=0.01, nombre_salida="expB1.27.gp")

# %%
archivo_gp = "expB1.27.gp"
subprocess.run(["gnuplot", archivo_gp])

# %% [markdown]
# ## B = 0.48, $\rho = 1207$

# %%
PROJECT_ROOT = "/media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH"
BASE_ROOT = f"{PROJECT_ROOT}/Output/experiments_B/experiment_B0.483293/Output/state_0000.txt"

generar_script_gnuplot(BASE_ROOT, lim=499, retardo=0.01, nombre_salida="expB0.48.gp")

# %%
archivo_gp = "expB0.48.gp"
subprocess.run(["gnuplot", archivo_gp])

# %% [markdown]
# ## B = 0.30, $\rho = 1244$

# %%
PROJECT_ROOT = "/media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH"
BASE_ROOT = f"{PROJECT_ROOT}/Output/experiments_B/experiment_B0.297635/Output/state_0000.txt"

generar_script_gnuplot(BASE_ROOT, lim=499, retardo=0.01, nombre_salida="expB0.30.gp")

# %%
archivo_gp = "expB0.30.gp"
subprocess.run(["gnuplot", archivo_gp])

# %% [markdown]
# ## B = 0.18, $\rho = 1284$

# %%
PROJECT_ROOT = "/media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH"
BASE_ROOT = f"{PROJECT_ROOT}/Output/experiments_B/experiment_B0.183298/Output/state_0000.txt"

generar_script_gnuplot(BASE_ROOT, lim=499, retardo=0.01, nombre_salida="expB0.18.gp")

# %%
archivo_gp = "expB0.18.gp"
subprocess.run(["gnuplot", archivo_gp])

# %% [markdown]
# ## B = 0.01, $\rho = 1572$

# %%
PROJECT_ROOT = "/media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH"
BASE_ROOT = f"{PROJECT_ROOT}/Output/experiments_B/experiment_B0.010000/Output/state_0000.txt"

generar_script_gnuplot(BASE_ROOT, lim=499, retardo=0.01, nombre_salida="expB0.01.gp")

# %%
archivo_gp = "expB0.01.gp"
subprocess.run(["gnuplot", archivo_gp])

# %% [markdown]
# #### Se decide usar B = 0.48 y c = 0.001, se ejecutarán hasta 10000 pasos de estabilización

# %% [markdown]
# ### Se hace la transferencia del codigo a un arhivo .py para llamar desde otra ubicación.

# %%
from gnuplotModifier import simple_script_gnuplot
import subprocess

PROJECT_ROOT = "/media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH"
SELECTED_ROOT = f"{PROJECT_ROOT}/Output/experiments_B/experiment_B0.483293/Output/state_0000.txt"

simple_script_gnuplot(SELECTED_ROOT, lim=499, retardo=0.01, nombre_salida="selected_expB0.48.gp")
# Out:
# ✅ Script Gnuplot generado correctamente: selected_expB0.48.gp
# 📊 Rangos consecutivos detectados por tipo:
#   Tipo 1: líneas 0–230 (231 partículas)
#   Tipo -1: líneas 231–321 (91 partículas)
#   Tipo 1: líneas 322–631 (310 partículas)
#   Tipo 0: líneas 632–2231 (1600 partículas)

# %%
archivo_gp = "selected_expB0.48.gp"
subprocess.run(["gnuplot", archivo_gp])
# Out:
# QSocketNotifier: Can only be used with threads started with QThread
# CompletedProcess(args=['gnuplot', 'selected_expB0.48.gp'], returncode=0)

# %%
from gnuplotModifier import simple_script_gnuplot
import subprocess

PROJECT_ROOT = "/media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH"
SELECTED_ROOT = f"{PROJECT_ROOT}/Output/exp_B_4x7k/experiment_B0.480000/Output/state_0000.txt"

simple_script_gnuplot(SELECTED_ROOT, lim=6999, retardo=0.001, nombre_salida="expB0.48_4x7k.gp")
# Out:
# ✅ Script Gnuplot generado correctamente: expB0.48_4x7k.gp
# 📊 Rangos consecutivos detectados por tipo:
#   Tipo 1: líneas 0–230 (231 partículas)
#   Tipo -1: líneas 231–321 (91 partículas)
#   Tipo 1: líneas 322–631 (310 partículas)
#   Tipo 0: líneas 632–2231 (1600 partículas)

# %%
archivo_gp = "expB0.48_4x7k.gp"
subprocess.run(["gnuplot", archivo_gp])
# Out:
# QSocketNotifier: Can only be used with threads started with QThread
# CompletedProcess(args=['gnuplot', 'expB0.48_4x7k.gp'], returncode=0)

# %% [markdown]
# ### Generando gnuplot para manual_ics

# %%
from gnuplotModifier import simple_script_gnuplot
import subprocess

PROJECT_ROOT = "/media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH"
SELECTED_ROOT = f"{PROJECT_ROOT}/Output/Manual_ics/output/state_0000.txt"

simple_script_gnuplot(SELECTED_ROOT, lim=99, retardo=1, nombre_salida="manual_ics.gp")
# Out:
# ✅ Script Gnuplot generado correctamente: manual_ics.gp
# 📊 Rangos consecutivos detectados por tipo:
#   Tipo 1: líneas 0–81 (82 partículas)
#   Tipo 0: líneas 82–105 (24 partículas)
#   Tipo 1: líneas 106–109 (4 partículas)
#   Tipo 0: líneas 110–133 (24 partículas)
#   Tipo 1: líneas 134–137 (4 partículas)
#   Tipo 0: líneas 138–161 (24 partículas)
#   Tipo 1: líneas 162–165 (4 partículas)
#   Tipo 0: líneas 166–189 (24 partículas)
#   Tipo 1: líneas 190–193 (4 partículas)
#   Tipo 0: líneas 194–217 (24 partículas)
#   Tipo 1: líneas 218–221 (4 partículas)
#   Tipo 0: líneas 222–245 (24 partículas)
#   Tipo 1: líneas 246–249 (4 partículas)
#   Tipo 0: líneas 250–273 (24 partículas)
#   Tipo 1: líneas 274–277 (4 partículas)
#   Tipo 0: líneas 278–301 (24 partículas)
#   Tipo 1: líneas 302–305 (4 partículas)
#   Tipo 0: líneas 306–329 (24 partículas)
#   Tipo 1: líneas 330–333 (4 partículas)
#   Tipo 0: líneas 334–357 (24 partículas)
#   Tipo 1: líneas 358–361 (4 partículas)
#   Tipo 0: líneas 362–385 (24 partículas)
#   Tipo 1: líneas 386–387 (2 partículas)
#   Tipo 0: líneas 388–411 (24 partículas)
#   Tipo 1: líneas 412–415 (4 partículas)
#   Tipo 0: líneas 416–439 (24 partículas)
#   Tipo 1: líneas 440–443 (4 partículas)
#   Tipo 0: líneas 444–467 (24 partículas)
#   Tipo 1: líneas 468–471 (4 partículas)
#   Tipo 0: líneas 472–495 (24 partículas)
#   Tipo 1: líneas 496–499 (4 partículas)
#   Tipo 0: líneas 500–523 (24 partículas)
#   Tipo 1: líneas 524–527 (4 partículas)
#   Tipo 0: líneas 528–551 (24 partículas)
#   Tipo 1: líneas 552–555 (4 partículas)
#   Tipo 0: líneas 556–579 (24 partículas)
#   Tipo 1: líneas 580–583 (4 partículas)
#   Tipo 0: líneas 584–607 (24 partículas)
#   Tipo 1: líneas 608–611 (4 partículas)
#   Tipo 0: líneas 612–635 (24 partículas)
#   Tipo 1: líneas 636–639 (4 partículas)
#   Tipo 0: líneas 640–663 (24 partículas)
#   Tipo 1: líneas 664–667 (4 partículas)
#   Tipo 0: líneas 668–691 (24 partículas)
#   Tipo 1: líneas 692–695 (4 partículas)
#   Tipo 0: líneas 696–719 (24 partículas)
#   Tipo 1: líneas 720–723 (4 partículas)
#   Tipo 0: líneas 724–747 (24 partículas)
#   Tipo 1: líneas 748–751 (4 partículas)
#   Tipo 0: líneas 752–775 (24 partículas)
#   Tipo 1: líneas 776–779 (4 partículas)
#   Tipo 0: líneas 780–803 (24 partículas)
#   Tipo 1: líneas 804–807 (4 partículas)
#   Tipo 0: líneas 808–831 (24 partículas)
#   Tipo 1: líneas 832–835 (4 partículas)
#   Tipo 0: líneas 836–859 (24 partículas)
#   Tipo 1: líneas 860–863 (4 partículas)
#   Tipo 0: líneas 864–887 (24 partículas)
#   Tipo 1: líneas 888–889 (2 partículas)
#   Tipo 0: líneas 890–913 (24 partículas)
#   Tipo 1: líneas 914–917 (4 partículas)
#   Tipo 0: líneas 918–941 (24 partículas)
#   Tipo 1: líneas 942–945 (4 partículas)
#   Tipo 0: líneas 946–969 (24 partículas)
#   Tipo 1: líneas 970–973 (4 partículas)
#   Tipo 0: líneas 974–997 (24 partículas)
#   Tipo 1: líneas 998–1001 (4 partículas)
#   Tipo 0: líneas 1002–1025 (24 partículas)
#   Tipo 1: líneas 1026–1029 (4 partículas)
#   Tipo 0: líneas 1030–1053 (24 partículas)
#   Tipo 1: líneas 1054–1057 (4 partículas)
#   Tipo 0: líneas 1058–1081 (24 partículas)
#   Tipo 1: líneas 1082–1085 (4 partículas)
#   Tipo 0: líneas 1086–1109 (24 partículas)
#   Tipo 1: líneas 1110–1113 (4 partículas)
#   Tipo 0: líneas 1114–1137 (24 partículas)
#   Tipo 1: líneas 1138–1141 (4 partículas)
#   Tipo 0: líneas 1142–1165 (24 partículas)
#   Tipo 1: líneas 1166–1169 (4 partículas)
#   Tipo 0: líneas 1170–1193 (24 partículas)
#   Tipo 1: líneas 1194–1275 (82 partículas)
#   Tipo -1: líneas 1276–1291 (16 partículas)
#   Tipo 1: líneas 1292–1515 (224 partículas)
