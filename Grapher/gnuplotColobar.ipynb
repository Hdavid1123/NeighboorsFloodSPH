# %%
from utils.gnuplotModifier import simple_script_gnuplot
from utils.gnuplotColorbar import color_bar_script_gnuplot
import subprocess

BASE_ROOT = "/media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH/Output"
SELECTED_ROOT = f"{BASE_ROOT}/vaciado_caida4k/Output"

# %%
from utils.plot_colorbar import plot_ics_color

plot_ics_color(f"{SELECTED_ROOT}/state_0320.txt",
               prop = "rho",
               vmin = 800,
               vmax = 1800)

# %%
color_bar_script_gnuplot(
    carpeta = SELECTED_ROOT,
    variable_color="rho",
    lim=11999,
    retardo=0.01,
    nombre_salida="plot_animacion.gp")
# Out:
# Script Gnuplot generado correctamente: plot_animacion.gp
#
# Variable usada para color: rho (columna $8)
#
# Rango usado para colorbar: [375.8086023421, 1770.7175874244]
#
# Paleta: TURBO-like (stops generados en valores absolutos)

# %%
plot_ics_color(f"{SELECTED_ROOT}/state_0320.txt",
               prop = "pressure",
               vmin = ,
               vmax = 1800)
