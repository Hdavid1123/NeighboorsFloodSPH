# %%
import json
from pathlib import Path
from datetime import datetime
import numpy as np

# ========================= CONFIGURACIÓN ========================= #
PROJECT_ROOT = Path().resolve().parent    # ruta raíz del proyecto, por ejemplo: /home/usuario/FloodSPH/base

# Archivo JSON base (parámetros originales)
base_json_path = PROJECT_ROOT / "Config" / "parameters" / "simulation" / "AndresSimParams.json"

# Carpeta de salida principal
OutputSim = PROJECT_ROOT / "Output"

# Carpeta donde se guardarán los experimentos con c modificado
manual_ics_root = OutputSim / "Manual_ics"
manual_ics_root.mkdir(parents=True, exist_ok=True)

# Leer archivo base
with open(base_json_path, "r") as f:
    base_params = json.load(f)

# Copia profunda del JSON base
params = json.loads(json.dumps(base_params))

# Actualizar archivo de ingreso y carpeta de salida
sim_output_dir = manual_ics_root / "output"
sim_output_dir.mkdir(parents=True, exist_ok=True)
params["io"]["input_file"] = str(manual_ics_root / "cuadrilateros_manuales.txt")
params["io"]["output_dir_simulation"] = str(sim_output_dir)

# Actualizar parámetros físicos
params["physics"]["eos_params"]["monaghan"]["c"] = 1e-3
params["physics"]["eos_params"]["monaghan"]["B"] = 0.48

# Actualizar número de pasos
params["integrator"]["n_steps"] = 100

# Guardar el archivo modificado de parámetros
param_file = manual_ics_root / "manual_quads.json"
with open(param_file, "w") as f:
    json.dump(params, f, indent=2)

print(f"✅ Generado: {param_file.relative_to(PROJECT_ROOT)}")
# Out:
# ✅ Generado: Output/Manual_ics/manual_quads.json

# %%
import subprocess

sim_executable = PROJECT_ROOT / "simulacion" 

param_file = manual_ics_root / "manual_quads.json"
subprocess.run([str(sim_executable), str(param_file)])
# Out:
# [INFO] Leyendo parámetros desde: /media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH/Output/Manual_ics/manual_quads.json
# [INFO] Configurada EoS Monaghan con parámetros:
#        B=0.48, c=0.001, rho0=1000, gamma=7
# Dentro de función de lectura de partículas
# Separación dx/dy de frontera: 0, 0
# Separación dx/dy de fluido: 0, 0
# Error: tipo desconocido para partícula ID=1276
# Error: tipo desconocido para partícula ID=1277
# Error: tipo desconocido para partícula ID=1278
# Error: tipo desconocido para partícula ID=1279
# Error: tipo desconocido para partícula ID=1280
# Error: tipo desconocido para partícula ID=1281
# Error: tipo desconocido para partícula ID=1282
# Error: tipo desconocido para partícula ID=1283
# Error: tipo desconocido para partícula ID=1284
# Error: tipo desconocido para partícula ID=1285
# Error: tipo desconocido para partícula ID=1286
# Error: tipo desconocido para partícula ID=1287
# Error: tipo desconocido para partícula ID=1288
# Error: tipo desconocido para partícula ID=1289
# Error: tipo desconocido para partícula ID=1290
# Error: tipo desconocido para partícula ID=1291
# Primera partícula de frontera:
#   ID: 0 pos: (0, 0)
#   tipo: Frontera
#  h: 2.75e-05
# Última partícula de fluido:
#   ID: 1193 pos: (0.00098, 0.00058)
#   tipo: Fluido
#  h: 2.75e-05
# Se leyeron 1516 partículas desde el archivo /media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH/Output/Manual_ics/cuadrilateros_manuales.txt
#
# [particleSummary] Número total de partículas: 1516
# Fluido: 960, Ancho: 0.00096, Altura: 0.00056
# Frontera: 556, Ancho: 0.002, Altura: 0.002
# [INFO] Ejecutando test del kernel...
# Prueba del kernel completada.
# Resultados guardados en: Output/tests/kernel_test.output
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# [testNeighbors] Ejecución test de vecinos...
# particle 607 tipo: 0 con 12 vecinos
# particle 1327 tipo: 1 con 8 vecinos
# particle 1415 tipo: 1 con 8 vecinos
# particle 1265 tipo: 1 con 8 vecinos
# particle 1511 tipo: 1 con 8 vecinos
# particle 760 tipo: 0 con 20 vecinos
# particle 1033 tipo: 0 con 20 vecinos
# particle 1091 tipo: 0 con 20 vecinos
# particle 1073 tipo: 0 con 20 vecinos
# particle 1191 tipo: 0 con 21 vecinos
# particle 1011 tipo: 0 con 20 vecinos
# particle 862 tipo: 1 con 16 vecinos
# particle 1288 tipo: -1 con 14 vecinos
# particle 896 tipo: 0 con 20 vecinos
# particle 734 tipo: 0 con 20 vecinos
# particle 1290 tipo: -1 con 14 vecinos
# particle 1343 tipo: 1 con 8 vecinos
# particle 1340 tipo: 1 con 8 vecinos
# particle 823 tipo: 0 con 20 vecinos
# particle 1435 tipo: 1 con 8 vecinos
# particle 621 tipo: 0 con 20 vecinos
# particle 732 tipo: 0 con 20 vecinos
# particle 1291 tipo: -1 con 16 vecinos
# particle 750 tipo: 1 con 15 vecinos
# particle 1468 tipo: 1 con 8 vecinos
# particle 1150 tipo: 0 con 22 vecinos
# particle 1487 tipo: 1 con 8 vecinos
# particle 635 tipo: 0 con 12 vecinos
# particle 861 tipo: 1 con 8 vecinos
# particle 650 tipo: 0 con 20 vecinos
# Resultados de testNeighbors escritos en Output/tests/NN_test.output ✅
#
# Uso densidad normalizada
#
# Step 0 completado, tiempo = 5e-05
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 1 completado, tiempo = 0.0001
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 2 completado, tiempo = 0.00015
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 3 completado, tiempo = 0.0002
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 4 completado, tiempo = 0.00025
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 5 completado, tiempo = 0.0003
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 6 completado, tiempo = 0.00035
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 7 completado, tiempo = 0.0004
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 8 completado, tiempo = 0.00045
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 9 completado, tiempo = 0.0005
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 10 completado, tiempo = 0.00055
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 11 completado, tiempo = 0.0006
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 12 completado, tiempo = 0.00065
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 13 completado, tiempo = 0.0007
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 14 completado, tiempo = 0.00075
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 15 completado, tiempo = 0.0008
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 16 completado, tiempo = 0.00085
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 17 completado, tiempo = 0.0009
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 18 completado, tiempo = 0.00095
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 19 completado, tiempo = 0.001
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 20 completado, tiempo = 0.00105
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 21 completado, tiempo = 0.0011
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 22 completado, tiempo = 0.00115
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 23 completado, tiempo = 0.0012
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 24 completado, tiempo = 0.00125
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 25 completado, tiempo = 0.0013
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 26 completado, tiempo = 0.00135
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 27 completado, tiempo = 0.0014
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 28 completado, tiempo = 0.00145
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 29 completado, tiempo = 0.0015
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 30 completado, tiempo = 0.00155
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 31 completado, tiempo = 0.0016
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 32 completado, tiempo = 0.00165
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 33 completado, tiempo = 0.0017
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 34 completado, tiempo = 0.00175
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 35 completado, tiempo = 0.0018
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 36 completado, tiempo = 0.00185
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 37 completado, tiempo = 0.0019
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 38 completado, tiempo = 0.00195
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 39 completado, tiempo = 0.002
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 40 completado, tiempo = 0.00205
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 41 completado, tiempo = 0.0021
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 42 completado, tiempo = 0.00215
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 43 completado, tiempo = 0.0022
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 44 completado, tiempo = 0.00225
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 45 completado, tiempo = 0.0023
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 46 completado, tiempo = 0.00235
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 47 completado, tiempo = 0.0024
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 48 completado, tiempo = 0.00245
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 49 completado, tiempo = 0.0025
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 50 completado, tiempo = 0.00255
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 51 completado, tiempo = 0.0026
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 52 completado, tiempo = 0.00265
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 53 completado, tiempo = 0.0027
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 54 completado, tiempo = 0.00275
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 55 completado, tiempo = 0.0028
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 56 completado, tiempo = 0.00285
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 57 completado, tiempo = 0.0029
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 58 completado, tiempo = 0.00295
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 59 completado, tiempo = 0.003
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 60 completado, tiempo = 0.00305
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 61 completado, tiempo = 0.0031
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 62 completado, tiempo = 0.00315
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 63 completado, tiempo = 0.0032
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 64 completado, tiempo = 0.00325
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 65 completado, tiempo = 0.0033
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 66 completado, tiempo = 0.00335
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 67 completado, tiempo = 0.0034
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 68 completado, tiempo = 0.00345
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 69 completado, tiempo = 0.0035
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 70 completado, tiempo = 0.00355
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 71 completado, tiempo = 0.0036
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 72 completado, tiempo = 0.00365
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 73 completado, tiempo = 0.0037
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 74 completado, tiempo = 0.00375
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 75 completado, tiempo = 0.0038
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 76 completado, tiempo = 0.00385
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 77 completado, tiempo = 0.0039
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 78 completado, tiempo = 0.00395
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 79 completado, tiempo = 0.004
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 80 completado, tiempo = 0.00405
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 81 completado, tiempo = 0.0041
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 82 completado, tiempo = 0.00415
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 83 completado, tiempo = 0.0042
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 84 completado, tiempo = 0.00425
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 85 completado, tiempo = 0.0043
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 86 completado, tiempo = 0.00435
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 87 completado, tiempo = 0.0044
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 88 completado, tiempo = 0.00445
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 89 completado, tiempo = 0.0045
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 90 completado, tiempo = 0.00455
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 91 completado, tiempo = 0.0046
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 92 completado, tiempo = 0.00465
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 93 completado, tiempo = 0.0047
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 94 completado, tiempo = 0.00475
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 95 completado, tiempo = 0.0048
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 96 completado, tiempo = 0.00485
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 97 completado, tiempo = 0.0049
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 98 completado, tiempo = 0.00495
#
# [findNeighborsBruteForce] Buscando vecinos (Fuerza Bruta)...
# Total partículas: 1516, Fluido: 960
# Búsqueda de vecinos completada ✅
#
# Uso densidad normalizada
#
# Step 99 completado, tiempo = 0.005
#
# Duración total del ciclo (100 pasos) = 6.63809 s
# CompletedProcess(args=['/media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH/simulacion', '/media/hvarkaed/a2e590e8-6eb4-4da7-a766-06b1247531ca/FloodSPH/Output/Manual_ics/manual_quads.json'], returncode=0)
